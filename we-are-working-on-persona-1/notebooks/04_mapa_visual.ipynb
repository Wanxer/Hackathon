# %% [markdown]
# # 04 — Mapa baseline real
#
# Genera `outputs/mapa_baseline.html` amb:
#
# - depot DDI Mollet
# - els 24 clients reals
# - ordre baseline inferit amb `Entrega`
# - geometria de carretera OSRM
# - llegenda amb ruta, data, clients, km i temps total

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
elif not (ROOT / 'data').exists():
    ROOT = Path('..').resolve()

sys.path.insert(0, str(ROOT))
print(f'Project root: {ROOT}')

# %%
from scripts.p1_pipeline import build_map, validate_deliverables

map_path = build_map(ROOT)
print(f'Mapa generat: {map_path}')

# %% [markdown]
# ## Validació final de lliurables P1

# %%
checks = validate_deliverables(ROOT)
checks
